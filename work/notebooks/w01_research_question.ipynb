# %% [markdown]
# <a href="https://colab.research.google.com/github/hanamonem/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/hanamonem/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# My Lane: CTR Prediction

# I chose the CTR Prediction lane because click-through rate is an important measure of search performance.

# Pages with low CTR may represent opportunities for improvement even when they receive impressions.

# I want to explore whether search performance features can help identify pages that are likely to have lower CTR.

# This may help prioritize optimization efforts and focus attention on pages that could benefit from improvements.

# The starter dataset shows variation in page performance metrics, which suggests that this question is worth exploring.

# For this reason, I believe CTR Prediction is a practical and relevant lane for the capstone project.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# Research Question

# Can we predict which pages are likely to achieve lower CTR based on search performance features?

# Unit of Analysis

# The unit of analysis is a web page.

# Output

# The output will be a prediction of whether a page is likely to have low or high CTR.

# Decision

# Which pages should be prioritized for optimization?

# Who Acts on It

# An SEO specialist, content manager, or website owner would use the recommendation.

# Action

# Pages predicted to have low CTR could be reviewed and improved by updating titles, meta descriptions, and content.

# Cost of a Wrong Recommendation

# If the prediction is incorrect, time and effort may be spent optimizing pages that do not need improvement.

# Pages with more important optimization opportunities may be overlooked.

# Why Data and ML Can Help

# Search performance data contains patterns that may help identify pages likely to receive lower CTR.

# Machine learning may help discover these patterns and support decision-making across many pages.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# Quick Look at the Data

# I explored the starter dataset to understand whether CTR Prediction is a useful problem to investigate.

# The code cell below calculates statistics from the dataset.

# These numbers provide evidence about variation in search performance metrics.

# The observations are based on the real values produced by the code cell below.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# Careful Words

# The observations in this notebook are exploratory and based on the available dataset.

# The results may suggest relationships between variables, but they do not prove causation.

# Any findings should be interpreted as patterns observed in the data rather than evidence of how search engines work.

# Additional analysis and validation would be required before making strong business recommendations.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
